# %% [markdown]
# The autoreload instruction reloads modules automatically before code execution, which is helpful for the update below.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Make sure that we have the latest version of pandas-profiling.

# %%
import sys

!"{sys.executable}" -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in c:\users\doduo\anaconda3\lib\site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.1.4)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\doduo\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.60.0)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\doduo\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (7.8.1)
# Requirement already satisfied: PyWavelets in c:\users\doduo\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.7.0)
# Requirement already satisfied: pillow in c:\users\doduo\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (10.4.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\doduo\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (2.1.3)
# Requirement already satisfied: notebook in c:\users\doduo\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.2.2)
# Requirement already satisfied: qtconsole in c:\users\doduo\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\doduo\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\doduo\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\doduo\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.28.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\doduo\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\doduo\anaconda3\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling[notebook]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\doduo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\doduo\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\doduo\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\doduo\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\doduo\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\doduo\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\doduo\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\doduo\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\doduo\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\doduo\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\doduo\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (0.5.6)
# Requirement already satisfied: colorama in c:\users\doduo\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\doduo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\doduo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.3)
# Requirement already satisfied: puremagic in c:\users\doduo\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (1.28)
# Requirement already satisfied: decorator in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\doduo\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\doduo\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\doduo\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\doduo\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\doduo\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\doduo\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (6.4.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\doduo\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->ydata-profiling[notebook]) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\doduo\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\doduo\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\doduo\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\doduo\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\doduo\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.5)
# Requirement already satisfied: executing in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\doduo\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\doduo\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\doduo\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\doduo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.1)
# Requirement already satisfied: uri-template in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\doduo\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\doduo\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\doduo\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.3)
# Requirement already satisfied: jupyter-contrib-nbextensions in c:\users\doduo\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.7.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.16.4)
# Requirement already satisfied: notebook>=6.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.2.2)
# Requirement already satisfied: tornado in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.14.3)
# Requirement already satisfied: lxml in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (75.1.0)
# Requirement already satisfied: jupyter-server in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.10.4)
# Requirement already satisfied: packaging in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\doduo\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (305.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\doduo\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\doduo\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\doduo\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\doduo\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\doduo\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\doduo\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\doduo\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\doduo\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\doduo\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\doduo\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\doduo\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\doduo\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2024.1)
# Requirement already satisfied: certifi in c:\users\doduo\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\doduo\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\doduo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil in c:\users\doduo\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\doduo\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\doduo\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\doduo\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.3)
# Requirement already satisfied: decorator in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: colorama in c:\users\doduo\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.4.6)
# Requirement already satisfied: fqdn in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.1)
# Requirement already satisfied: uri-template in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\doduo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\doduo\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\doduo\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\doduo\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\doduo\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\doduo\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.2.3)
# Requirement already satisfied: executing in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\doduo\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# qtconsole run script server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %% [markdown]
# You might want to restart the kernel now.

# %%
# Standard Library Imports
from pathlib import Path

# Installed packages
import pandas as pd
from ipywidgets import widgets

# Our package
from ydata_profiling import ProfileReport
from ydata_profiling.utils.cache import cache_file
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# Read the Titanic Dataset
file_name = cache_file(
    "titanic.csv",
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",
)
df = pd.read_csv(file_name)

# %%
# Generate the Profiling Report
profile = ProfileReport(
    df, title="Titanic Dataset", html={"style": {"full_width": True}}, sort=None
)

# %%
# The Notebook Widgets Interface
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 260.88it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # The Notebook Widgets Interface
# ----> 2 profile.to_widgets()
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:544, in ProfileReport.to_widgets(self)
#     540     pass
#     542 from IPython.display import display
# --> 544 display(self.widgets)
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:314, in ProfileReport.widgets(self)
#     309     raise RuntimeError(
#     310         "Widgets interface not (yet) supported for comparing reports, please use the HTML rendering."
#     311     )
#     313 if self._widgets is None:
# --> 314     self._widgets = self._render_widgets()
#     315 return self._widgets
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:447, in ProfileReport._render_widgets(self)
#     439 report = self.report
#     441 with tqdm(
#     442     total=1,
#     443     desc="Render widgets",
#     444     disable=not self.config.progress_bar,
#     445     leave=False,
#     446 ) as pbar:
# --> 447     widgets = WidgetReport(copy.deepcopy(report)).render()
#     448     pbar.update()
#     449 return widgets
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\root.py:9, in WidgetRoot.render(self, **kwargs)
#       7 def render(self, **kwargs) -> widgets.VBox:
#       8     return widgets.VBox(
# ----> 9         [self.content["body"].render(), self.content["footer"].render()]
#      10     )
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\container.py:106, in WidgetContainer.render(self)
#     104     widget = get_named_list(self.content["items"])
#     105 elif self.sequence_type in ["tabs", "sections", "select"]:
# --> 106     widget = get_tabs(self.content["items"])
#     107 elif self.sequence_type == "accordion":
#     108     widget = get_accordion(self.content["items"])
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\container.py:20, in get_tabs(items)
#      18 titles = []
#      19 for item in items:
# ---> 20     children.append(item.render())
#      21     titles.append(get_name(item))
#      23 tab = widgets.Tab()
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\container.py:119, in WidgetContainer.render(self)
#     112     widget = get_batch_grid(
#     113         self.content["items"],
#     114         self.content["batch_size"],
#     115         self.content.get("titles", True),
#     116         self.content.get("subtitles", False),
#     117     )
#     118 else:
# --> 119     raise ValueError("widget type not understood", self.sequence_type)
#     121 return widget
#
# ValueError: ('widget type not understood', 'overview_tabs')

# %%
# Or use the HTML report in an iframe
profile
